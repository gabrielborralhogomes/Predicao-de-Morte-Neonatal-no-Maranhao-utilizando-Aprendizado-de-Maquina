# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Juntar bases de dados

# %%
# Pasta onde estão os arquivos CSV
pasta_csv = 'C:\\Users\\gabie\\OneDrive\\Área de Trabalho\\ebac\\projetos\\predicao_neonatal\\dados\\SIM'

# Lista para armazenar todos os DataFrames
dataframes = []

# Loop pelos anos de 2017 até 2023
for ano in range(2017, 2024):
    nome_arquivo = f'Mortalidade_Geral_{ano}.csv'
    caminho_completo = os.path.join(pasta_csv, nome_arquivo)
    
    if os.path.exists(caminho_completo):
        df = pd.read_csv(caminho_completo, sep=';', low_memory=False)
        
        if 'CODMUNNATU' in df.columns:
            df_filtrado = df[df['CODMUNNATU'].astype(str).str.startswith("21")]
            
            if not df_filtrado.empty:
                # Converte DTNASC para numérico, lidando com erros usando .loc[]
                df_filtrado.loc[:, 'DTNASC'] = pd.to_numeric(df_filtrado['DTNASC'], errors='coerce')

                # Filtra apenas as linhas válidas (sem NaN)
                df_filtrado = df_filtrado[df_filtrado['DTNASC'].notna()]

                # Extrai o ano de nascimento com base no formato
                def extrair_ano(dt):
                    dt_str = str(int(dt))  # Remove o decimal
                    return int(dt_str[-4:])  # Extrai os últimos quatro dígitos como ano

                # Aplica a função para criar a coluna de ano de nascimento
                df_filtrado['ano_nascimento'] = df_filtrado['DTNASC'].apply(extrair_ano)
                
                # Aplica o filtro para manter aqueles que nasceram entre 2017 e 2022 e IDADE <= 227
                df_filtrado = df_filtrado[(df_filtrado['ano_nascimento'].between(2017, 2022)) & (df_filtrado['IDADE'] <= 227)]
                
                dataframes.append(df_filtrado)
                print(f'Arquivo {nome_arquivo} carregado e filtrado com sucesso.')
            else:
                print(f'Arquivo {nome_arquivo} não contém códigos que começam com "21".')
        else:
            print(f'Coluna "CODMUNNATU" não encontrada no arquivo {nome_arquivo}. Colunas disponíveis: {df.columns.tolist()}')
    else:
        print(f'Arquivo {nome_arquivo} não encontrado.')

# Junta todos os DataFrames filtrados em um único
if dataframes:
    df_completo = pd.concat(dataframes, ignore_index=True)
    df_completo.to_csv('C:\\Users\\gabie\\OneDrive\\Área de Trabalho\\ebac\\projetos\\predicao_neonatal\\dados\\SIM\\SIM_MA.csv', sep=';', index=False)
    print("Todos os arquivos CSV foram combinados com sucesso!")
else:
    print("Nenhum arquivo CSV foi combinado, pois nenhum contém códigos que começam com '21'.")
# Out:
# Arquivo Mortalidade_Geral_2017.csv carregado e filtrado com sucesso.
# Arquivo Mortalidade_Geral_2018.csv carregado e filtrado com sucesso.
# Arquivo Mortalidade_Geral_2019.csv carregado e filtrado com sucesso.
# Arquivo Mortalidade_Geral_2020.csv carregado e filtrado com sucesso.
# Arquivo Mortalidade_Geral_2021.csv carregado e filtrado com sucesso.
# Arquivo Mortalidade_Geral_2022.csv carregado e filtrado com sucesso.
# Arquivo Mortalidade_Geral_2023.csv carregado e filtrado com sucesso.
# Todos os arquivos CSV foram combinados com sucesso!

# %% [markdown]
# # Remover dados

# %%
df_sim = pd.read_csv('C:\\Users\\gabie\\OneDrive\\Área de Trabalho\\ebac\\projetos\\predicao_neonatal\\dados\\SIM//SIM_MA.csv', 
                     low_memory=False, sep=";")
pd.set_option('display.max_rows', None)  
pd.set_option('display.max_columns', None)

# %%
df_sim.rename(columns={'CODMUNNATU': 'CODMUNNASC'}, inplace=True)

# %%
df_sim.head().T
# Out:
#                              0               1               2           3  \
# CONTADOR                  12.0            52.0           110.0       178.0
# ORIGEM                       1               1               1           1
# TIPOBITO                     2               2               2           2
# DTOBITO               10032017        21032017        17032017     1072017
# HORAOBITO                845.0           700.0          2350.0      2100.0
# NATURAL                  821.0           821.0           821.0       821.0
# CODMUNNASC            210690.0        211050.0        210330.0    210910.0
# DTNASC               9032017.0      15032017.0      17032017.0   1072017.0
# IDADE                      201             206             107         101
# SEXO                         1               2               2           1
# RACACOR                    1.0             4.0             4.0         1.0
# ESTCIV                     NaN             NaN             NaN         NaN
# ESC                        NaN             NaN             NaN         NaN
# ESC2010                    NaN             NaN             NaN         NaN
# SERIESCFAL                 NaN             NaN             NaN         NaN
# OCUP                       NaN             NaN             NaN         NaN
# CODMUNRES               210690          211050          210330      210910
# LOCOCOR                      1               1               1           1
# CODESTAB             7321252.0       2458799.0       2449641.0   2455145.0
# ESTABDESCR                 NaN             NaN             NaN         NaN
# CODMUNOCOR              210690          211130          210330      210910
# IDADEMAE                  19.0            21.0            30.0        22.0
# ESCMAE                     4.0             9.0             3.0         4.0
# ESCMAE2010                 2.0             9.0             2.0         3.0
# SERIESCMAE                 8.0             NaN             NaN         NaN
# OCUPMAE               631105.0        622020.0        622020.0    521110.0
# QTDFILVIVO                 2.0             2.0             5.0         2.0
# QTDFILMORT                 0.0             0.0             0.0         NaN
# GRAVIDEZ                   1.0             1.0             1.0         1.0
# SEMAGESTAC                40.0            31.0            38.0        33.0
# GESTACAO                   5.0             3.0             5.0         4.0
# PARTO                      2.0             1.0             1.0         1.0
# OBITOPARTO                 3.0             3.0             3.0         3.0
# PESO                    3025.0          1500.0          3010.0      2900.0
# TPMORTEOCO                 NaN             NaN             8.0         NaN
# OBITOGRAV                  NaN             NaN             2.0         NaN
# OBITOPUERP                 NaN             NaN             3.0         NaN
# ASSISTMED                  1.0             1.0             NaN         NaN
# EXAME                      NaN             NaN             NaN         NaN
# CIRURGIA                   NaN             NaN             NaN         NaN
# NECROPSIA                  2.0             2.0             NaN         2.0
# LINHAA                   *P369           *P543           *P219       *P073
# LINHAB                   *P239           *P369           *P285       *P220
# LINHAC                   *P240           *P071           *P240         NaN
# LINHAD                     NaN             NaN             NaN         NaN
# LINHAII                    NaN             NaN             NaN         NaN
# CAUSABAS                  P240            P369            P240        P220
# CB_PRE                     NaN             NaN             NaN         NaN
# COMUNSVOIM                 NaN             NaN             NaN         NaN
# DTATESTADO          10032017.0      21032017.0      22032017.0   1072017.0
# CIRCOBITO                  NaN             NaN             NaN         NaN
# ACIDTRAB                   NaN             NaN             NaN         NaN
# FONTE                      NaN             NaN             NaN         NaN
# NUMEROLOTE          20170003.0      20180025.0      20170038.0  20180005.0
# TPPOS                      NaN               N               S           S
# DTINVESTIG                 NaN             NaN      25092017.0  25092017.0
# CAUSABAS_O                 J15            P369            P240        P220
# DTCADASTRO          23032017.0      23032017.0      24032017.0  13072017.0
# ATESTANTE                  1.0             1.0             1.0         1.0
# STCODIFICA                   S               S               S           S
# CODIFICADO                   S               S               S           S
# VERSAOSIST              3.2.00          3.2.02          3.2.00      3.2.02
# VERSAOSCB                  3.2             3.2             3.2         3.2
# FONTEINV                   NaN             NaN             8.0         3.0
# DTRECEBIM           28032017.0      30052018.0      27092017.0  21032018.0
# ATESTADO        P369/P239/P240  P543/P369/P071  P219/P285/P240   P073/P220
# DTRECORIGA            28032017        24032017        28032017    13072017
# CAUSAMAT                   NaN             NaN             NaN         NaN
# ESCMAEAGR1                 4.0             9.0            11.0        12.0
# ESCFALAGR1                 NaN             NaN             NaN         NaN
# STDOEPIDEM                 0.0             0.0             0.0         0.0
# STDONOVA                     1               1               1           1
# DIFDATA                     18             435             194         263
# NUDIASOBCO                 NaN             NaN             NaN         NaN
# NUDIASOBIN                 NaN             NaN             NaN         NaN
# DTCADINV                   NaN             NaN             NaN         NaN
# TPOBITOCOR                 NaN             NaN             NaN         NaN
# DTCONINV                   NaN             NaN             NaN         NaN
# FONTES                  SXXSXX          SXXSXX          SXSXXX      SXSSXX
# TPRESGINFO                 NaN             NaN             NaN         NaN
# TPNIVELINV                 NaN             NaN             NaN         NaN
# NUDIASINF                  NaN             NaN             NaN         NaN
# DTCADINF            27122018.0      27102017.0      27092017.0  25092017.0
# MORTEPARTO                 3.0             3.0             3.0         3.0
# DTCONCASO            8102018.0      26102017.0      25092017.0  25092017.0
# FONTESINF                  NaN             NaN             NaN         NaN
# ALTCAUSA                   2.0             2.0             2.0         2.0
# ano_nascimento            2017            2017            2017        2017
# contador                   NaN             NaN             NaN         NaN
#
#                          4
# CONTADOR             184.0
# ORIGEM                   1
# TIPOBITO                 2
# DTOBITO            5062017
# HORAOBITO           1640.0
# NATURAL              821.0
# CODMUNNASC        210047.0
# DTNASC          22052017.0
# IDADE                  214
# SEXO                     2
# RACACOR                1.0
# ESTCIV                 NaN
# ESC                    NaN
# ESC2010                NaN
# SERIESCFAL             NaN
# OCUP                   NaN
# CODMUNRES           210047
# LOCOCOR                  1
# CODESTAB         2772299.0
# ESTABDESCR             NaN
# CODMUNOCOR          210990
# IDADEMAE              19.0
# ESCMAE                 4.0
# ESCMAE2010             3.0
# SERIESCMAE             3.0
# OCUPMAE           999992.0
# QTDFILVIVO             0.0
# QTDFILMORT             0.0
# GRAVIDEZ               1.0
# SEMAGESTAC            37.0
# GESTACAO               5.0
# PARTO                  1.0
# OBITOPARTO             3.0
# PESO                2800.0
# TPMORTEOCO             NaN
# OBITOGRAV              NaN
# OBITOPUERP             NaN
# ASSISTMED              1.0
# EXAME                  NaN
# CIRURGIA               NaN
# NECROPSIA              2.0
# LINHAA               *R578
# LINHAB               *A392
# LINHAC                 NaN
# LINHAD                 NaN
# LINHAII                NaN
# CAUSABAS              A392
# CB_PRE                 NaN
# COMUNSVOIM             NaN
# DTATESTADO       5062017.0
# CIRCOBITO              NaN
# ACIDTRAB               NaN
# FONTE                  NaN
# NUMEROLOTE      20170007.0
# TPPOS                    S
# DTINVESTIG       5062017.0
# CAUSABAS_O            A392
# DTCADASTRO       9062017.0
# ATESTANTE              1.0
# STCODIFICA               S
# CODIFICADO               S
# VERSAOSIST          3.2.02
# VERSAOSCB              3.2
# FONTEINV               3.0
# DTRECEBIM       16062017.0
# ATESTADO         R578/A392
# DTRECORIGA        16062017
# CAUSAMAT               NaN
# ESCMAEAGR1             6.0
# ESCFALAGR1             NaN
# STDOEPIDEM             0.0
# STDONOVA                 1
# DIFDATA                 11
# NUDIASOBCO             NaN
# NUDIASOBIN             NaN
# DTCADINV               NaN
# TPOBITOCOR             NaN
# DTCONINV               NaN
# FONTES              XXSXXX
# TPRESGINFO             NaN
# TPNIVELINV             NaN
# NUDIASINF              NaN
# DTCADINF        30062017.0
# MORTEPARTO             3.0
# DTCONCASO       30062017.0
# FONTESINF              NaN
# ALTCAUSA               2.0
# ano_nascimento        2017
# contador               NaN

# %%
len(df_sim)
# Out:
# 5535

# %%
df_sim.isnull().sum().sum()
# Out:
# 200362

# %%
colunas_para_trabalhar = [
 'DTNASC',
 'SEXO',
 'CODMUNNASC',
 'GESTACAO',
 'PARTO',
 'IDADEMAE',
 'RACACOR',
 'ESCMAE'
]

# %%
df_sim_trab = df_sim[colunas_para_trabalhar]

# %%
df_sim_trab.head().T
# Out:
#                     0           1           2          3           4
# DTNASC      9032017.0  15032017.0  17032017.0  1072017.0  22052017.0
# SEXO              1.0         2.0         2.0        1.0         2.0
# CODMUNNASC   210690.0    211050.0    210330.0   210910.0    210047.0
# GESTACAO          5.0         3.0         5.0        4.0         5.0
# PARTO             2.0         1.0         1.0        1.0         1.0
# IDADEMAE         19.0        21.0        30.0       22.0        19.0
# RACACOR           1.0         4.0         4.0        1.0         1.0
# ESCMAE            4.0         9.0         3.0        4.0         4.0

# %%
df_sim_trab = df_sim_trab.dropna()

# %%
len(df_sim_trab)
# Out:
# 4123

# %%
df_sim_trab = df_sim_trab.drop_duplicates()

# %%
len(df_sim_trab)
# Out:
# 4090

# %%
df_sim_trab = df_sim_trab.astype(float)

# %%
df_sim_trab.to_csv('C:\\Users\\gabie\\OneDrive\\Área de Trabalho\\ebac\\projetos\\predicao_neonatal\\dados\\SIM\\SIM_MA_V1_REM.csv')
